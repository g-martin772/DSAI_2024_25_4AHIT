# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
iris = load_iris()
featureData = iris.data
targetLabels = iris.target

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(featureData, targetLabels, test_size=0.2, random_state=42)

# %%
# Train a RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=300, max_depth=200, random_state=42)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=200, n_estimators=300, random_state=42)

# %%
# Make predictions
y_pred = classifier.predict(X_test)

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 100.00%

# %%
# Visualize the feature importances
importances = classifier.feature_importances_
indices = np.argsort(importances)[::-1]

plt.figure()
plt.title("Feature importances")
plt.bar(range(featureData.shape[1]), importances[indices], align="center")
plt.xticks(range(featureData.shape[1]), iris.feature_names, rotation=90)
plt.xlim([-1, featureData.shape[1]])
plt.show()

# %%
# Show confusion metrics
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# Create heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['setosa', 'versicolor', 'virginica'],
            yticklabels=['setosa', 'versicolor', 'virginica'])
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# %%
# Map numbers to species names
species_names = {0: 'setosa', 1: 'versicolor', 2: 'virginica'}

for features, actual, predicted in zip(X_test, y_test, y_pred):
    print(f"{features} | {species_names[actual]} | {species_names[predicted]}")
# Out:
# [6.1 2.8 4.7 1.2] | versicolor | versicolor
# [5.7 3.8 1.7 0.3] | setosa | setosa
# [7.7 2.6 6.9 2.3] | virginica | virginica
# [6.  2.9 4.5 1.5] | versicolor | versicolor
# [6.8 2.8 4.8 1.4] | versicolor | versicolor
# [5.4 3.4 1.5 0.4] | setosa | setosa
# [5.6 2.9 3.6 1.3] | versicolor | versicolor
# [6.9 3.1 5.1 2.3] | virginica | virginica
# [6.2 2.2 4.5 1.5] | versicolor | versicolor
# [5.8 2.7 3.9 1.2] | versicolor | versicolor
# [6.5 3.2 5.1 2. ] | virginica | virginica
# [4.8 3.  1.4 0.1] | setosa | setosa
# [5.5 3.5 1.3 0.2] | setosa | setosa
# [4.9 3.1 1.5 0.1] | setosa | setosa
# [5.1 3.8 1.5 0.3] | setosa | setosa
# [6.3 3.3 4.7 1.6] | versicolor | versicolor
# [6.5 3.  5.8 2.2] | virginica | virginica
# [5.6 2.5 3.9 1.1] | versicolor | versicolor
# [5.7 2.8 4.5 1.3] | versicolor | versicolor
# [6.4 2.8 5.6 2.2] | virginica | virginica
# [4.7 3.2 1.6 0.2] | setosa | setosa
# [6.1 3.  4.9 1.8] | virginica | virginica
# [5.  3.4 1.6 0.4] | setosa | setosa
# ...
